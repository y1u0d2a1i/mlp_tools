# %%
from mlptools.analyzer.yamamura_tawara import YamamuraTawaraSputteringYieldCalculator

# %%
yt_calculator = YamamuraTawaraSputteringYieldCalculator(projectile="Ar", target="Si")

# %%
import numpy as np
energy_list = [10, 50, 100, 200 ,350, 500, 750, 1000]
sp = yt_calculator.get_sputtering_yield(
    energy_list=energy_list
)
# Out:
# /Users/y1u0d2/Desktop/Project/mlp_tools/mlptools/analyzer/yamamura_tawara.py:160: RuntimeWarning: invalid value encountered in power
#   C = (1-np.sqrt(eth/E))**s

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(energy_list, sp, marker='o', label='data')
